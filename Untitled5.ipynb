# %%
install.packages("tidyverse")
library(tidyverse) #pacote para manipulacao de dados
install.packages("cluster")
library(cluster) #algoritmo de cluster
install.packages("dendextend")
library(dendextend) #compara dendogramas
install.packages("factoextra")
library(factoextra) #algoritmo de cluster e visualizacao
install.packages("fpc")
library(fpc) #algoritmo de cluster e visualizacao
install.packages("gridExtra")
library(gridExtra) #para a funcao grid arrange
library(readxl)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5b617ceb9285> in <module>()
# ----> 1 install.packages("tidyverse")
#       2 library(tidyverse) #pacote para manipulacao de dados
#       3 install.packages("cluster")
#       4 library(cluster) #algoritmo de cluster
#       5 install.packages("dendextend")
#
# NameError: name 'install' is not defined

# %%
# dados de coagulation
dados1<-c(-1.6,1.1,-4.1,-2.6,-0.6,-4.5,-1,3.1,-0.8,-0.4,0.5,-3.4,-0.4,3.7,-2.5,-0.8,1.4,-3.4,-2,-4.1,-9.9,-1.2,3.7,-6.8,-1.2,2,-3.4,-2.6,0.2,0.8,-0.6,3.4,0,0,0.8,-2.5,-0.6,4,-4.1,2.7,0,-3.4,-2.7,-3.8,-6.6,-3.3,1.4,-3.4,-1.2,1.7,-3.4,-1.8,3.1,-7.3,-0.6,4,0,0,1.4,-1.7,-0.6,4,-3.4,-2.1,3.7,-7.3,-2.4,2.4,-5.7,-3,-4.7,-11.8,-1,2.4,-2.5,-3.1,-3.6,-4.5,-0.4,3.7,0,0,1.1,-2.5,-0.6,3.7,-4.1,2,-3.5,-0.1,-3.3,-0.6,-6.6,-2.1,-0.6,-2.5,-1,3.1,-2.5,-3.6,-2.8,-2.5,-0.4,4,0,0,1.4,-1.7,-0.6,3.4,-3.4,-1.6,3.7,-1.7,-1.4,-1.2,-6.8,0.6,3.4,0.8)
ks.test(dados1, "pnorm", mean(Residuos), sd(Residuos))
