# %%
# ALGORITMO R PARA GERAR CLUSTERS
install.packages("tidyverse")
library(tidyverse) #pacote para manipulacao de dados
install.packages("cluster")
library(cluster) #algoritmo de cluster
install.packages("dendextend")
library(dendextend) #compara dendogramas
install.packages("factoextra")
library(factoextra) #algoritmo de cluster e visualizacao
install.packages("fpc")
library(fpc) #algoritmo de cluster e visualizacao
install.packages("gridExtra")
library(gridExtra) #para a funcao grid arrange
library(readxl)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-22dcd2963d1d> in <module>()
#       1 # ALGORITMO R PARA GERAR CLUSTERS
# ----> 2 install.packages("tidyverse")
#       3 library(tidyverse) #pacote para manipulacao de dados
#       4 install.packages("cluster")
#       5 library(cluster) #algoritmo de cluster
#
# NameError: name 'install' is not defined
