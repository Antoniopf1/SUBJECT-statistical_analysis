# %%
# Analise descritiva de amostras
# Trabalhando com dados
import pandas as pd
# Gráficos
import matplotlib.pyplot as plt
import seaborn as sns
# Gerando dados
import numpy as np
import statistics

# %%
# Entrada de dados
x1=np.array([60,59.5,62,62,59,60,60,59.5,62,61,61,61.5,60.5,60.5])
x2=np.array([64,65,63.5,63.5,65,64,64.5,64.5,65,64.5,63,65,63.5,64])
x=np.array([1.72,1.78,1.87,1.86,1.79,1.79,1.83,1.74,1.64,1.62,1.75,1.65,1.75,1.58,1.63,1.77,1.64,1.68,1.66,1.82,1.68,1.8,1.74,1.76,1.74,1.72,1.75,1.89,1.73,1.76,1.72,1.71,1.63,1.81,1.65,1.58,1.63,1.7,1.73,1.57,1.75,1.64,1.73,1.7,1.75,1.56,1.7,1.68,1.68,1.79,1.75,1.71,1.62,1.83,1.72,1.76,1.67,1.82,1.67,1.6,1.67,1.61,1.61,1.67,1.75,1.8,1.7,1.77,1.73,1.77,1.64,1.66,1.74,1.66,1.66,1.79,1.68,1.79,1.69,1.8])

# %%
# estatisticas descritivas
statistics.mean(x2)
# Out:
# 64.21428571428571

# %%
statistics.stdev(x)
# Out:
# 0.07375968076347075

# %%
statistics.median(x)
# Out:
# 1.72

# %%
statistics.mode(x)
# Out:
# 1.75

# %%
plt.style.use('seaborn-deep')
bins = np.linspace(1.5,2.0,17)
plt.hist([x], bins, label=['Altura'])
plt.legend(loc='upper left')
plt.show()

# %%
# Dotplot
fig, ax=plt.subplots()
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.plot(x, 'ro')
plt.show()
